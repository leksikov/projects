# %%
import numpy as np
import pandas as pd

import numpy as np
from pandas.tseries.offsets import BDay
import math
import random

import matplotlib.pyplot as plt

import seaborn as sns; sns.set()
# %matplotlib inline

from pyfinance import TSeries

from hurst import compute_Hc, random_walk


from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler


from sklearn.decomposition import PCA


from sklearn.cluster import KMeans

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
sns.set(rc={'figure.figsize':(15,12)})

# %%
import rwi

# %%
def load_df(name):
    eurusd_df = pd.read_csv(name)
    eurusd_df = eurusd_df.rename(columns={'<TICKER>':'Ticker', '<DTYYYYMMDD>':'Date', '<TIME>':'Time', '<OPEN>':'Open', '<HIGH>':'High', '<LOW>':'Low', '<CLOSE>':'Close', '<VOL>':'Vol'})
    eurusd_df[['Date']] = pd.to_datetime(eurusd_df['Date'].astype('str'), yearfirst=True)
    eurusd_df =eurusd_df.sort_values(by=['Date', 'Time'])
    eur_df = eurusd_df[['Date', 'Time', 'Close', 'Vol']].rename(columns={'Close':'price'})
    eur_df['returns'] = eur_df['price'].pct_change()
    eur_df.dropna(inplace=True)
    #eur_df = eur_df[eur_df.Date>'2020-01-01']
    #eur_df = eur_df.set_index('Date')
    return eur_df

# %%
name='data/fxcm/eurusd_1d.csv'
eur_df = load_df(name)

# %%
eur_df = rwi.generate_features(eur_df).fillna(0)

# %%
#eur_df = eur_df.set_index('Date')

# %%
eur_df['abs_returns'] = eur_df.returns.abs()
eur_df['atr_14'] = eur_df.returns.rolling(14).std().fillna(0)
eur_df['atr_50'] = eur_df.returns.rolling(50).std().fillna(0)
eur_df['atr_200'] = eur_df.returns.rolling(200).std().fillna(0)

# %%
eur_df
# Out:
#            Date  Time    price     Vol   returns     ROC_2     ROC_3  \
# 1    2010-03-02     0  1.36185   44046  0.000000  0.000000  0.000000
# 2    2010-03-03     0  1.36993   58804  0.019154  0.000000  0.000000
# 3    2010-03-04     0  1.35806   54033 -0.027648 -0.009024  0.000000
# 4    2010-03-05     0  1.36194   37976  0.009322 -0.018584  0.000214
# 5    2010-03-07     0  1.36359    1891  0.003920  0.013278 -0.014737
# ...         ...   ...      ...     ...       ...       ...       ...
# 3090 2020-03-22     0  1.06888   28400 -0.006279  0.051009 -0.260667
# 3091 2020-03-23     0  1.07634  360567  0.104412  0.097477  0.160747
# 3092 2020-03-24     0  1.07977  288802  0.043249  0.152176  0.144942
# 3093 2020-03-25     0  1.08881  266724  0.108632  0.156579  0.277340
# 3094 2020-03-26     0  1.10469  243643  0.170175  0.297293  0.353400
#
#          ROC_5    ROC_20    ROC_50   ROC_100   ROC_200   ROC_500  abs_returns  \
# 1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.019154
# 3     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.027648
# 4     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.009322
# 5     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.003920
# ...        ...       ...       ...       ...       ...       ...          ...
# 3090 -0.394600 -0.298432 -0.335864 -0.349059 -0.414259 -0.573177     0.006279
# 3091 -0.239589 -0.248120 -0.246094 -0.281030 -0.324677 -0.521815     0.104412
# 3092 -0.148158 -0.232235 -0.212830 -0.241837 -0.290445 -0.478352     0.043249
# 3093  0.342496 -0.214342 -0.123156 -0.123320 -0.215122 -0.415090     0.108632
# 3094  0.485325 -0.104573  0.023381  0.022999 -0.067340 -0.313717     0.170175
#
#         atr_14    atr_50   atr_200
# 1     0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.000000
# 5     0.000000  0.000000  0.000000
# ...        ...       ...       ...
# 3090  0.094797  0.061322  0.038523
# 3091  0.099372  0.063194  0.039142
# 3092  0.097454  0.063538  0.039266
# 3093  0.104112  0.065454  0.040022
# 3094  0.115731  0.069756  0.041784
#
# [3094 rows x 17 columns]

# %%
### 1. PCA, k-means clustering

# %%
eur_df.columns
# Out:
# Index(['Date', 'Time', 'price', 'Vol', 'returns', 'ROC_2', 'ROC_3', 'ROC_5',
#        'ROC_20', 'ROC_50', 'ROC_100', 'ROC_200', 'ROC_500', 'abs_returns',
#        'atr_14', 'atr_50', 'atr_200'],
#       dtype='object')

# %%
X = eur_df.copy().drop(columns=['Time', 'price' ,'Vol', 'returns', 'abs_returns', 'ROC_2', 'ROC_3', 'ROC_5', 'ROC_20', 'atr_14'])

# %%
X = X.set_index('Date')

# %%
pca = PCA(n_components=3)

pca_X = pca.fit_transform(X.fillna(0)) 

print(pca.explained_variance_ratio_)

print(pca.singular_values_)
# Out:
# [0.57691947 0.25276697 0.10630753]
# [34.83883938 23.06036847 14.95505809]

# %%
pca_X = pd.DataFrame(pca_X, columns=['p1', 'p2', 'p3'])

# %%
#1
ax = sns.scatterplot(x='p3', y='p2', data=pca_X)

# %%
ax = sns.pairplot( data=pca_X)

# %%
kmeans = KMeans(n_clusters=6, random_state=0).fit(pca_X)
kmeans.labels_

y = kmeans.predict(pca_X)

kmeans.cluster_centers_
# Out:
# array([[ 2.09148497, -0.66695749, -0.36901233],
#        [ 0.04897259,  0.10834498, -0.02682018],
#        [-0.63525117,  0.00850707, -0.0890698 ],
#        [ 0.70665203,  1.24328512,  0.16419442],
#        [ 0.99896123,  0.06554526, -0.02712166],
#        [-0.07702045, -0.37770837,  0.17859856]])

# %%
X = X.reset_index()
X['cluster'] = y
X['price'] = eur_df.price

# %%
eur_df.price
# Out:
# 1       1.36185
# 2       1.36993
# 3       1.35806
# 4       1.36194
# 5       1.36359
#          ...
# 3090    1.06888
# 3091    1.07634
# 3092    1.07977
# 3093    1.08881
# 3094    1.10469
# Name: price, Length: 3094, dtype: float64

# %%
eur_df
# Out:
#            Date  Time    price     Vol   returns     ROC_2     ROC_3  \
# 1    2010-03-02     0  1.36185   44046  0.000000  0.000000  0.000000
# 2    2010-03-03     0  1.36993   58804  0.019154  0.000000  0.000000
# 3    2010-03-04     0  1.35806   54033 -0.027648 -0.009024  0.000000
# 4    2010-03-05     0  1.36194   37976  0.009322 -0.018584  0.000214
# 5    2010-03-07     0  1.36359    1891  0.003920  0.013278 -0.014737
# ...         ...   ...      ...     ...       ...       ...       ...
# 3090 2020-03-22     0  1.06888   28400 -0.006279  0.051009 -0.260667
# 3091 2020-03-23     0  1.07634  360567  0.104412  0.097477  0.160747
# 3092 2020-03-24     0  1.07977  288802  0.043249  0.152176  0.144942
# 3093 2020-03-25     0  1.08881  266724  0.108632  0.156579  0.277340
# 3094 2020-03-26     0  1.10469  243643  0.170175  0.297293  0.353400
#
#          ROC_5    ROC_20    ROC_50   ROC_100   ROC_200   ROC_500  abs_returns  \
# 1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.019154
# 3     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.027648
# 4     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.009322
# 5     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000     0.003920
# ...        ...       ...       ...       ...       ...       ...          ...
# 3090 -0.394600 -0.298432 -0.335864 -0.349059 -0.414259 -0.573177     0.006279
# 3091 -0.239589 -0.248120 -0.246094 -0.281030 -0.324677 -0.521815     0.104412
# 3092 -0.148158 -0.232235 -0.212830 -0.241837 -0.290445 -0.478352     0.043249
# 3093  0.342496 -0.214342 -0.123156 -0.123320 -0.215122 -0.415090     0.108632
# 3094  0.485325 -0.104573  0.023381  0.022999 -0.067340 -0.313717     0.170175
#
#         atr_14    atr_50   atr_200
# 1     0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.000000
# 3     0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.000000
# 5     0.000000  0.000000  0.000000
# ...        ...       ...       ...
# 3090  0.094797  0.061322  0.038523
# 3091  0.099372  0.063194  0.039142
# 3092  0.097454  0.063538  0.039266
# 3093  0.104112  0.065454  0.040022
# 3094  0.115731  0.069756  0.041784
#
# [3094 rows x 17 columns]

# %%
X.index.max()
# Out:
# 3093

# %%
X
# Out:
#            Date    ROC_20    ROC_50   ROC_100   ROC_200   ROC_500    atr_14  \
# 0    2010-03-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    2010-03-03  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    2010-03-04  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    2010-03-05  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    2010-03-07  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 3089 2020-03-22 -0.298432 -0.335864 -0.349059 -0.414259 -0.573177  0.094797
# 3090 2020-03-23 -0.248120 -0.246094 -0.281030 -0.324677 -0.521815  0.099372
# 3091 2020-03-24 -0.232235 -0.212830 -0.241837 -0.290445 -0.478352  0.097454
# 3092 2020-03-25 -0.214342 -0.123156 -0.123320 -0.215122 -0.415090  0.104112
# 3093 2020-03-26 -0.104573  0.023381  0.022999 -0.067340 -0.313717  0.115731
#
#         atr_50   atr_200  cluster    price
# 0     0.000000  0.000000        1      NaN
# 1     0.000000  0.000000        1  1.36185
# 2     0.000000  0.000000        1  1.36993
# 3     0.000000  0.000000        1  1.35806
# 4     0.000000  0.000000        1  1.36194
# ...        ...       ...      ...      ...
# 3089  0.061322  0.038523        2  1.06933
# 3090  0.063194  0.039142        2  1.06888
# 3091  0.063538  0.039266        2  1.07634
# 3092  0.065454  0.040022        2  1.07977
# 3093  0.069756  0.041784        5  1.08881
#
# [3094 rows x 11 columns]

# %%
sns.scatterplot(x=X.loc['2020-02-20':].reset_index().index, y=X.loc['2020-02-20':]['price'], hue='cluster', data=X.loc['2020-02-20':][['price', 'cluster']])

# %%
X[['price', 'cluster']].plot(subplots=(2,1))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D59555DD08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D59557E048>],
#       dtype=object)

# %%
ax = sns.scatterplot(x='p1', y='p2', hue=y, data=pca_X)

# %%
X
# Out:
#              returns     ROC_2     ROC_3     ROC_5    ROC_20    ROC_50  \
# Date
# 2010-03-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-03-03  0.019154  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-03-04 -0.027648 -0.009024  0.000000  0.000000  0.000000  0.000000
# 2010-03-05  0.009322 -0.018584  0.000214  0.000000  0.000000  0.000000
# 2010-03-07  0.003920  0.013278 -0.014737  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2020-03-22 -0.006279  0.051009 -0.260667 -0.394600 -0.298432 -0.335864
# 2020-03-23  0.104412  0.097477  0.160747 -0.239589 -0.248120 -0.246094
# 2020-03-24  0.043249  0.152176  0.144942 -0.148158 -0.232235 -0.212830
# 2020-03-25  0.108632  0.156579  0.277340  0.342496 -0.214342 -0.123156
# 2020-03-26  0.170175  0.297293  0.353400  0.485325 -0.104573  0.023381
#
#              ROC_100   ROC_200   ROC_500  abs_returns    atr_14  cluster  \
# Date
# 2010-03-02  0.000000  0.000000  0.000000     0.000000  0.000000        1
# 2010-03-03  0.000000  0.000000  0.000000     0.019154  0.000000        1
# 2010-03-04  0.000000  0.000000  0.000000     0.027648  0.000000        1
# 2010-03-05  0.000000  0.000000  0.000000     0.009322  0.000000        1
# 2010-03-07  0.000000  0.000000  0.000000     0.003920  0.000000        1
# ...              ...       ...       ...          ...       ...      ...
# 2020-03-22 -0.349059 -0.414259 -0.573177     0.006279  0.094797        5
# 2020-03-23 -0.281030 -0.324677 -0.521815     0.104412  0.099372        5
# 2020-03-24 -0.241837 -0.290445 -0.478352     0.043249  0.097454        5
# 2020-03-25 -0.123320 -0.215122 -0.415090     0.108632  0.104112        5
# 2020-03-26  0.022999 -0.067340 -0.313717     0.170175  0.115731        3
#
#               price
# Date
# 2010-03-02  1.36185
# 2010-03-03  1.36993
# 2010-03-04  1.35806
# 2010-03-05  1.36194
# 2010-03-07  1.36359
# ...             ...
# 2020-03-22  1.06888
# 2020-03-23  1.07634
# 2020-03-24  1.07977
# 2020-03-25  1.08881
# 2020-03-26  1.10469
#
# [3094 rows x 13 columns]

# %%
# optimal set of indicators, critical adding wrong indicator messes up everythng
# PCA, HMM, GMM or auto-encoders are effective?
# what are paramters
# what is number of clusters?
# we have clusters regimes. Which one will help to outperform market?
# how to deal with multiple regimes?
# how to know that success wasnt due to random chance?

# %%
# what is definition of good cluster?
# good good result looks like?
# how it can be measured?

# %%
X.atr_50.hist(bins=50)

# %%
thresh = eur_df.atr_50.mean()

# %%
eur_df['regime'] = eur_df['atr_50'].apply(lambda x: 1 if x > thresh else 0)

# %%
eur_df['shift_returns'] = eur_df.returns.shift(-1).fillna(0)

# %%
eur_df[eur_df.Date > '2016-01-01'][['price', 'regime']].plot(subplots=(2,1))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D583D0FF08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001D584578148>],
#       dtype=object)

# %%
eur_df[eur_df.regime==1].reset_index().shift_returns.cumsum().plot()

# %%
eur_df[eur_df.regime==1].shift_returns.mean() * 100
# Out:
# 0.29020674523226253

# %%
eur_df[eur_df.regime==1].shape
# Out:
# (876, 19)

# %%
eur_df[eur_df.regime==1][['atr_14', 'returns', 'shift_returns']].plot.scatter(x='returns', y='shift_returns')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
eur_df[eur_df.regime==1].reset_index().price.plot()

# %%
eur_df[eur_df.regime==0].price.plot()

# %%
### finalize my strategies vectorized backtesting with performance results
# methods to analyze returns due to selection, clsutering
### pca overfit

### ML with shift roc by period amount
### implement backtesting of ML models including MA models
